# %% [markdown]
# IS 362
# Patrick Diaz
# Week 13 Disscussion Board

# %% [markdown]
# Overview
#
# LinkedIn uses recommender systems across different features
# - Job recommendations
# - Connection suggestions
# - Content feed
# - Skill recommendations

# %% [markdown]
# Scenario Design Analysis
#
# Question 1: Who are the Users?
#
# From a User perspective
# - Job seekers
# - Recruiters
# - Students
#
# From a Organization perspective
# - Increase engagement
# - Match candidates
# - Grow network
# - Support hiring
#
# Question 2: What are the Users trying to accomplish?
#
# User perspective
# - Find revelant job openings
# - Expand network
# - Improve career prospects
#
# Organization perspective
# - Increase job applicants
# - Imporve hiring rates
# - Monetize company
#
# Question 3: How does the system support those goals?
#
# LinkedIn Recommendations based off of:
# - Skills
# - Job Title
# - Industry
# - Education
# - Connections
# - Mutual connections
# - Company relationships
# - Jobs viewed
# - Jobs applied
# - Post liked
# - Searches

# %% [markdown]
# Reverse Engineering the system
#
# LinkedIn most likely uses:
# - Profile data
# - Job descriptions
# - Recruiter activity
# - Network connections

# %% [markdown]
# Conclusion
#
# The LinkedIn recommender system is effective at connecting users and providing opportunities for users and organizations by using profile data, networks, and behavior data like searches/ likes.
